# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------

# %%
# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:


raw_sensor_data = []

for i in range(1, 101):
    # Generate timestamp
    timestamp = datetime.datetime.now() - datetime.timedelta(
        minutes=random.randint(0, 10000)
    )
    timestamp_str = timestamp.strftime('%Y-%m-%d %H:%M:%S')

    # Generate unique device ID
    device_id = f"DEV{i:03d}"

    # Random device type
    device_type = random.choice(DEVICE_TYPES)

    # Random location
    location = random.choice(LOCATIONS)

    # Generate value based on device type range
    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    # Create tuple and add to list
    reading = (timestamp_str, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

# Display first 5 readings
print("First 5 Sensor Readings:")
for reading in raw_sensor_data[:5]:
    print(reading)

print("\nTotal Readings Generated:", len(raw_sensor_data))
# Out:
# --- Task 1: Data Generation and Basic Structures ---
# First 5 Sensor Readings:
# ('2026-06-06 01:51:52', 'DEV001', 'Humidity_Sensor', 'Warehouse', 46.23)
# ('2026-06-05 04:35:52', 'DEV002', 'Light_Sensor', 'OfficeB', 911.7)
# ('2026-06-06 05:26:52', 'DEV003', 'Light_Sensor', 'Lab1', 972.57)
# ('2026-06-08 10:45:52', 'DEV004', 'Pressure_Sensor', 'Lab2', 981.07)
# ('2026-06-04 14:33:52', 'DEV005', 'Pressure_Sensor', 'OfficeB', 1021.11)
#
# Total Readings Generated: 100

# %%
#1.2

temperature_readings = []

for i in raw_sensor_data:
    if i[2] == "Temperature_Sensor":
        d = {}
        d["timestamp"] = i[0]
        d["device_id"] = i[1]
        d["location"] = i[3]
        d["temperature_celsius"] = i[4]

        temperature_readings.append(d)

print(temperature_readings)
# Out:
# [{'timestamp': '2026-06-07 04:58:52', 'device_id': 'DEV007', 'location': 'Lab1', 'temperature_celsius': 19.32}, {'timestamp': '2026-06-04 06:04:52', 'device_id': 'DEV008', 'location': 'OfficeA', 'temperature_celsius': 21.95}, {'timestamp': '2026-06-04 03:59:52', 'device_id': 'DEV009', 'location': 'Warehouse', 'temperature_celsius': 18.67}, {'timestamp': '2026-06-07 08:34:52', 'device_id': 'DEV011', 'location': 'OfficeA', 'temperature_celsius': 26.67}, {'timestamp': '2026-06-08 21:55:52', 'device_id': 'DEV015', 'location': 'Lab2', 'temperature_celsius': 23.91}, {'timestamp': '2026-06-10 01:25:52', 'device_id': 'DEV017', 'location': 'Lab2', 'temperature_celsius': 21.9}, {'timestamp': '2026-06-08 06:06:52', 'device_id': 'DEV020', 'location': 'Warehouse', 'temperature_celsius': 24.73}, {'timestamp': '2026-06-08 14:44:52', 'device_id': 'DEV021', 'location': 'Lab1', 'temperature_celsius': 25.29}, {'timestamp': '2026-06-08 04:18:52', 'device_id': 'DEV029', 'location': 'Lab1', 'temperature_celsius': 28.41}, {'timestamp': '2026-06-10 06:12:52', 'device_id': 'DEV032', 'location': 'OfficeA', 'temperature_celsius': 18.89}, {'timestamp': '2026-06-10 08:46:52', 'device_id': 'DEV051', 'location': 'OfficeA', 'temperature_celsius': 18.62}, {'timestamp': '2026-06-04 07:34:52', 'device_id': 'DEV057', 'location': 'Lab1', 'temperature_celsius': 26.88}, {'timestamp': '2026-06-07 15:43:52', 'device_id': 'DEV061', 'location': 'Lab1', 'temperature_celsius': 29.74}, {'timestamp': '2026-06-08 07:34:52', 'device_id': 'DEV067', 'location': 'OfficeB', 'temperature_celsius': 28.13}, {'timestamp': '2026-06-03 23:53:52', 'device_id': 'DEV073', 'location': 'OfficeB', 'temperature_celsius': 20.94}, {'timestamp': '2026-06-06 12:18:52', 'device_id': 'DEV076', 'location': 'Lab1', 'temperature_celsius': 21.93}, {'timestamp': '2026-06-09 11:23:52', 'device_id': 'DEV078', 'location': 'Lab1', 'temperature_celsius': 18.59}, {'timestamp': '2026-06-05 09:00:52', 'device_id': 'DEV083', 'location': 'Warehouse', 'temperature_celsius': 20.33}, {'timestamp': '2026-06-08 01:13:52', 'device_id': 'DEV086', 'location': 'Lab1', 'temperature_celsius': 23.33}, {'timestamp': '2026-06-06 10:36:52', 'device_id': 'DEV088', 'location': 'Warehouse', 'temperature_celsius': 20.94}, {'timestamp': '2026-06-04 07:52:52', 'device_id': 'DEV095', 'location': 'Lab2', 'temperature_celsius': 25.32}, {'timestamp': '2026-06-06 06:32:52', 'device_id': 'DEV098', 'location': 'Warehouse', 'temperature_celsius': 24.08}]

# %%
#1.3

unique_locations = set()

for i in raw_sensor_data:
    unique_locations.add(i[3])

print(unique_locations)
# Out:
# {'OfficeA', 'Warehouse', 'Lab2', 'Lab1', 'OfficeB'}

# %%
#1.4
device_stats = {}

for i in raw_sensor_data:
    device_type = i[2]
    value = i[4]

    if device_type not in device_stats:
        device_stats[device_type] = (value, value)
    else:
        min_val, max_val = device_stats[device_type]

        if value < min_val:
            min_val = value

        if value > max_val:
            max_val = value

        device_stats[device_type] = (min_val, max_val)

print(device_stats)
# Out:
# {'Humidity_Sensor': (33.15, 77.65), 'Light_Sensor': (106.31, 994.12), 'Pressure_Sensor': (980.17, 1029.36), 'Temperature_Sensor': (18.59, 29.74)}

# %%
#1.5.1

print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_1)
print(sliced_readings_2)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# [('2026-06-07 04:24:52', 'DEV010', 'Pressure_Sensor', 'OfficeA', 1005.02), ('2026-06-07 08:34:52', 'DEV011', 'Temperature_Sensor', 'OfficeA', 26.67), ('2026-06-08 17:16:52', 'DEV012', 'Pressure_Sensor', 'Lab2', 1008.1), ('2026-06-10 00:20:52', 'DEV013', 'Pressure_Sensor', 'Warehouse', 1007.34), ('2026-06-07 19:14:52', 'DEV014', 'Light_Sensor', 'Lab1', 994.12), ('2026-06-08 21:55:52', 'DEV015', 'Temperature_Sensor', 'Lab2', 23.91), ('2026-06-03 21:58:52', 'DEV016', 'Light_Sensor', 'Warehouse', 879.5), ('2026-06-10 01:25:52', 'DEV017', 'Temperature_Sensor', 'Lab2', 21.9), ('2026-06-06 01:11:52', 'DEV018', 'Humidity_Sensor', 'Warehouse', 77.57), ('2026-06-07 10:47:52', 'DEV019', 'Light_Sensor', 'OfficeB', 252.06), ('2026-06-08 06:06:52', 'DEV020', 'Temperature_Sensor', 'Warehouse', 24.73)]
# [('2026-06-06 01:51:52', 'DEV001', 'Humidity_Sensor', 'Warehouse', 46.23), ('2026-06-10 06:58:52', 'DEV006', 'Humidity_Sensor', 'OfficeB', 52.13), ('2026-06-07 08:34:52', 'DEV011', 'Temperature_Sensor', 'OfficeA', 26.67), ('2026-06-03 21:58:52', 'DEV016', 'Light_Sensor', 'Warehouse', 879.5), ('2026-06-08 14:44:52', 'DEV021', 'Temperature_Sensor', 'Lab1', 25.29), ('2026-06-06 06:31:52', 'DEV026', 'Light_Sensor', 'Lab2', 829.18), ('2026-06-07 23:57:52', 'DEV031', 'Light_Sensor', 'Warehouse', 425.78), ('2026-06-07 05:48:52', 'DEV036', 'Pressure_Sensor', 'Warehouse', 1005.33), ('2026-06-07 10:50:52', 'DEV041', 'Humidity_Sensor', 'Warehouse', 33.15), ('2026-06-09 07:25:52', 'DEV046', 'Pressure_Sensor', 'OfficeA', 980.17), ('2026-06-10 08:46:52', 'DEV051', 'Temperature_Sensor', 'OfficeA', 18.62), ('2026-06-04 18:22:52', 'DEV056', 'Pressure_Sensor', 'OfficeA', 980.23), ('2026-06-07 15:43:52', 'DEV061', 'Temperature_Sensor', 'Lab1', 29.74), ('2026-06-07 19:58:52', 'DEV066', 'Pressure_Sensor', 'OfficeB', 1024.77), ('2026-06-08 07:13:52', 'DEV071', 'Pressure_Sensor', 'OfficeA', 1009.12), ('2026-06-06 12:18:52', 'DEV076', 'Temperature_Sensor', 'Lab1', 21.93), ('2026-06-03 23:50:52', 'DEV081', 'Light_Sensor', 'Lab2', 478.5), ('2026-06-08 01:13:52', 'DEV086', 'Temperature_Sensor', 'Lab1', 23.33), ('2026-06-10 01:39:52', 'DEV091', 'Light_Sensor', 'Warehouse', 617.12), ('2026-06-07 06:03:52', 'DEV096', 'Pressure_Sensor', 'OfficeA', 995.27)]

# %%
#1.5.2
substring_1 = sample_string[6:17]

# Reverse "Python"

substring_2 = sample_string[5::-1]

print(substring_1)
print(substring_2)
# Out:
# Programming
# nohtyP

# %%
#1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]

# Last 6 characters

device_type_suffix = fifth_reading_device_type[-6:]

print(fifth_reading_device_type)
print(device_type_suffix)
# Out:
# Pressure_Sensor
# Sensor

# %%
# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:

# target_location= []
def get_readings_by_location(raw_sensor_data, target_location):
    return [reading for reading in raw_sensor_data if reading[3] == target_location]

result = get_readings_by_location(raw_sensor_data, "Lab2")
print(result)
# Out:
# --- Task 2: Function Definitions and Usage ---
# [('2026-06-08 10:45:52', 'DEV004', 'Pressure_Sensor', 'Lab2', 981.07), ('2026-06-08 17:16:52', 'DEV012', 'Pressure_Sensor', 'Lab2', 1008.1), ('2026-06-08 21:55:52', 'DEV015', 'Temperature_Sensor', 'Lab2', 23.91), ('2026-06-10 01:25:52', 'DEV017', 'Temperature_Sensor', 'Lab2', 21.9), ('2026-06-06 06:31:52', 'DEV026', 'Light_Sensor', 'Lab2', 829.18), ('2026-06-07 11:35:52', 'DEV038', 'Light_Sensor', 'Lab2', 423.26), ('2026-06-05 23:42:52', 'DEV044', 'Pressure_Sensor', 'Lab2', 998.9), ('2026-06-05 05:35:52', 'DEV045', 'Humidity_Sensor', 'Lab2', 68.89), ('2026-06-05 09:12:52', 'DEV049', 'Humidity_Sensor', 'Lab2', 40.75), ('2026-06-04 23:35:52', 'DEV054', 'Pressure_Sensor', 'Lab2', 994.58), ('2026-06-05 12:50:52', 'DEV063', 'Pressure_Sensor', 'Lab2', 1029.23), ('2026-06-06 22:58:52', 'DEV079', 'Light_Sensor', 'Lab2', 360.52), ('2026-06-03 23:50:52', 'DEV081', 'Light_Sensor', 'Lab2', 478.5), ('2026-06-03 16:52:52', 'DEV082', 'Light_Sensor', 'Lab2', 840.08), ('2026-06-03 16:39:52', 'DEV087', 'Light_Sensor', 'Lab2', 974.06), ('2026-06-04 07:52:52', 'DEV095', 'Temperature_Sensor', 'Lab2', 25.32)]

# %%
#2.2


def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total_temperature = 0
    for reading in temp_data_list:
        total_temperature += reading["temperature_celsius"]

    return total_temperature / len(temp_data_list)

# %%
#2.3
def generate_report_line(reading_dict):

    return "[" + reading_dict["timestamp"] + "] Device " + \
           reading_dict["device_id"] + " at " + \
           reading_dict["location"] + ": " + \
           str(reading_dict["temperature_celsius"]) + "°C"

# %%
# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' already exists.

# %%
#3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 12 hours, 57 minutes.

# %%
# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

import random

random_values = [random.randint(100, 200) for _ in range(5)]

print("Random values:", random_values)
# Out:
# Random values: [175, 154, 145, 147, 168]

# %%
# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.

# Your code for Task 4.1 here:
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")


# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:
try:
    file = open(report_filename, "r")

    read_report_lines = file.readlines()

    file.close()

    print(read_report_lines[:3])

except IOError as e:
    print(e)
print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
# ['[2026-06-07 04:58:52] Device DEV007 at Lab1: 19.32°C\n', '[2026-06-04 06:04:52] Device DEV008 at OfficeA: 21.95°C\n', '[2026-06-04 03:59:52] Device DEV009 at Warehouse: 18.67°C\n']
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.

# %%
#excercise 1
import numpy as np

# Student scores in Math, Science, English

student1 = np.array([85, 90, 88])
student2 = np.array([80, 85, 82])
student3 = np.array([60, 70, 65])

print("Student 1:", student1)
print("Student 2:", student2)
print("Student 3:", student3)
# Out:
# Student 1: [85 90 88]
# Student 2: [80 85 82]
# Student 3: [60 70 65]

# %%
# Norms (overall performance)

norm1 = np.linalg.norm(student1)
norm2 = np.linalg.norm(student2)
norm3 = np.linalg.norm(student3)

print("\nNorm of Student 1:", norm1)
print("Norm of Student 2:", norm2)
print("Norm of Student 3:", norm3)

# Cosine Similarity Function

def cosine_similarity(a, b):
    dot_product = np.dot(a, b)
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)

    return dot_product / (norm_a * norm_b)

# Similarities

sim12 = cosine_similarity(student1, student2)
sim13 = cosine_similarity(student1, student3)
sim23 = cosine_similarity(student2, student3)

print("\nCosine Similarity")
print("Student1 vs Student2 =", sim12)
print("Student1 vs Student3 =", sim13)
print("Student2 vs Student3 =", sim23)
# Out:
# Norm of Student 1: 151.88482478509826
# Norm of Student 2: 142.64992113562488
# Norm of Student 3: 112.80514172678478
#
# Cosine Similarity
# Student1 vs Student2 = 0.9999834638895986
# Student1 vs Student3 = 0.9992185325456916
# Student2 vs Student3 = 0.9992763591709074
